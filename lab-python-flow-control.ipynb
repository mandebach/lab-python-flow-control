# %% [markdown]
# # Lab | Flow Control

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized
#
# In the last lab, you were starting an online store that sells various products. To ensure smooth operations, you developed a program that manages customer orders and inventory.
#
# You did so without using flow control. Let's go a step further and improve this code.
#
# Follow the steps below to complete the exercise:
#
# 1. Look at your code from the lab data structures, and improve repeated code with loops.
#
# 2. Instead of asking the user to input the name of three products that a customer wants to order, do the following:
#
#     a. Prompt the user to enter the name of a product that a customer wants to order.
#
#     b. Add the product name to the "customer_orders" set.
#
#     c. Ask the user if they want to add another product (yes/no).
#
#     d. Continue the loop until the user does not want to add another product.
#
# 3. Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for  the products that were ordered (those in "customer_orders").

# %%
# 1. Define a list call products
products = ["t-shirt", "mug", "hat", "book", "keychain"]
# Create an empty dictionary called inventory
inventory = {}

# For each product available in inventory, ask user to input quantity of product
for product in products:
    quantity = int(input(f"How many {product}s do you have? "))
    # Add each product as a key and each corresponding quantity as a value to the inventory dictionary
    inventory[product] = quantity
# Out:
# How many t-shirts do you have?  5
# How many mugs do you have?  5
# How many hats do you have?  5
# How many books do you have?  5
# How many keychains do you have?  5

# %%
print(inventory)
# Out:
# {'t-shirt': 5, 'mug': 5, 'hat': 5, 'book': 5, 'keychain': 5}

# %%
# 2a. Prompt the user to enter the name of a product that a customer wants to order.
customer_orders = set()

keep_adding = "yes"

# Continue the loop until the user does not want to add another product.
while keep_adding == "yes":
    # Prompt the user to enter the name of a product that a customer wants to order.
    product_name = input("Enter the name of the product you want to order: ").strip().lower()
    
# 2b. Add the product to the "customer_orders" set.
    customer_orders.add(product_name)
    
# 2c. 2d. Ask the user if they want to add another product (yes/no).
    keep_adding = input("Do you want to continue? (yes/no): ").strip().lower()
# Out:
# Enter the name of the product you want to order:  mug
# Do you want to continue? (yes/no):  yes
# Enter the name of the product you want to order:  hat
# Do you want to continue? (yes/no):  yes
# Enter the name of the product you want to order:  book
# Do you want to continue? (yes/no):  no

# %%
# 3. Update the inventory by subtracting 1 for each ordered product
for product in customer_orders:
    if product in inventory:
        inventory[product] -= 1

# Print the updated inventory on separate lines
print("\nUpdated Inventory:")
for product, quantity in inventory.items():
    print(f"{product}: {quantity}")
# Out:
# Updated Inventory:
# t-shirt: 5
# mug: 4
# hat: 4
# book: 4
# keychain: 5
